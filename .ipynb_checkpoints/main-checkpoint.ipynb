# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
img_w = 1280
img_h =  720
n_w   =    9 # number of corners in w (x)
n_h   =    6 # numbe

# %%
# Arrays to store object points and image points from all the images
objpoints = [] # 3D points in real world space
imgpoints = [] # 2D points in image plane

img_w = 1280
img_h =  720
n_w   =    9 # number of corners in w (x)
n_h   =    6 # number of corners in h (y)

objp = np.zeros((n_h * n_w, 3), np.float32)
objp[:,:2] = np.mgrid[0:n_w, 0:n_h].T.reshape(-1, 2) # x, y coordinate

# %%
def find_corners(img_name):
    img = cv2.imread(img_name)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    ret, corners = cv2.findChessboardCorners(gray, (n_w, n_h), None)
    return img, cornersZz

# %%
cal2, corners = find_corners('camera_cal/calibration2.jpg')
if corners is not None:
    cv2.drawChessboardCorners(cal2, (n_w, n_h), corners, True)
    plt.imshow(cal2)

# %%
for img_i in range(1, 21):
    img, corners = find_corners('camera_cal/calibration{}.jpg'.format(img_i))
    
    if corners is not None:
        imgpoints.append(corners)
        objpoints.append(objp)

# %%
ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(
    objpoints, imgpoints, gray.shape[::-1
                                    ], None, None)

dst = cv2.undistort(cal_img, mtx, dist, None, mtx)
plt.imshow(dst)

# %%
# Prepare object points, like (0,0,0), (1,0,0), (2,0,0) ... (7,5,0)
objp = np.zeros((n_w * n_h, 3), np.float32)
objp[:,:2] = np.mgrid[0:n_w, 0:n_h].T.reshape(-1, 2) # x, y coordinate

images = ['calibration1.jpg', 'calibration2.jpg']
for fname in images:
    img = cv2.imread('camera_cal/' + fname)
    # Convert image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    plt.imshow(gray)
    ret, corners = cv2.findChessboardCorners(gray, (n_w, n_h), None)
    # print(ret)
    # If corners are found, add object points, image points
    if ret == True:
        imgpoints.append(corners)
        objpoints.append(objp)

        # draw and display the corners
        chess = img.copy()
        cv2.drawChessboardCorners(chess, (n_w, n_h), corners, ret)
        plt.imshow(chess)

# %%
nx = 8#TODO: enter the number of inside corners in x
ny = 6#TODO: enter the number of inside corners in y

# Make a list of calibration images
fname = 'test_images/test1.jpg'
img = cv2.cvtColor(cv2.imread(fname), cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.show()

# %%
def crop(img):
    return img[400:-40, 160:-160]

# %%
cropped = crop(img)
plt.imshow(cropped)
plt.show()
